# %% [markdown]
# <a href="https://colab.research.google.com/github/PedroHenriqueMA/Overall_FIFA_Predictor/blob/main/Trabalho_Final_Fundamento_IA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**IDENTIFICACAO**
#
# **TITULO**: *Trabalho Final - Fundamentos da Inteligencia Artificial  grupo 14*
#
# **DISCENTES**:
# Pedro Henrique Moura Andrade,
# Ian Marcel Santos Santana,
# Luis Gustavo Santos.
#
# O dataset escolhido pode ser encontrado em https://www.kaggle.com/datasets/stefanoleone992/fifa-21-complete-player-dataset
# e traz atributos técnicos e físicos de jogadores de futebol.
#
# O objetivo é usar regressão para prever a nota geral (Overall)
# de um atleta com base em estatísticas específicas, como passe,
# finalização e minutagem.
#
# Atributo preditivo: Overall (nota geral)
#
# Atributos preditivos:
